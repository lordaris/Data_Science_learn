# %%
import pandas as pd
import numpy as np
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df_environment = pd.read_csv("datasets/environment_mex.csv")
df_environment.columns
# Out:
# Index(['Country Name', 'Country ISO3', 'Year', 'Indicator Name',
#        'Indicator Code', 'Value'],
#       dtype='object')

# %%
# Country Name, Country ISO3 and Indicator Code are unnecessary columns
df_environment.drop(['Country Name', 'Country ISO3', 'Indicator Code'], axis=1, inplace=True)

# Also row 0 is not necessary
df_environment.drop([0], inplace=True)

df_environment.head(1)
# Out:
#    Year                      Indicator Name             Value
# 1  2018  Agricultural land (% of land area)  54.9864965662697

# %% [markdown]
# ## I want to use the indicator name in different columns

# %%
pivot1 = pd.pivot_table(df_environment, index="Year", columns="Indicator Name", values="Value")
pivot1.head(1)
# Out:
# Indicator Name  Access to clean fuels and technologies for cooking (% of population)  \
# Year
# 1960                                                          NaN
# 1961                                                          NaN
#
# Indicator Name  Access to clean fuels and technologies for cooking, rural (% of rural population)  \
# Year
# 1960                                                          NaN
# 1961                                                          NaN
#
# Indicator Name  Access to clean fuels and technologies for cooking, urban (% of urban population)  \
# Year
# 1960                                                          NaN
# 1961                                                          NaN
#
# Indicator Name  Access to electricity (% of population)  \
# Year
# 1960                                                NaN
# 1961                                                NaN
#
# Indicator Name  Adjusted net savings, excluding particulate emission damage (% of GNI)  \
# Year
# 1960                                                          NaN
# 1961                                                          NaN
#
# Indicator Name  Adjusted net savings, excluding particulate emission damage (current US$)  \
# Year
# 1960                                                          NaN
# 1961                                                          NaN
#
# Indicator Name  Adjusted net savings, including particulate emission damage (% of GNI)  \
# Year
# 1960                                                          NaN
# 1961                                                          NaN
#
# Indicator Name  Adjusted net savings, including particulate emission damage (current US$)  \
# Year
# 1960                                                          NaN
# 1961                                                          NaN
#
# Indicator Name  Adjusted savings: carbon dioxide damage (% of GNI)  \
# Year
# 1960                                                          NaN
# 1961                                                          NaN
#
# Indicator Name  Adjusted savings: carbon dioxide damage (current US$)  ...  \
# Year                                                                   ...
# 1960                                                          NaN      ...
# 1961                                                          NaN      ...
#
# Indicator Name  Terrestrial protected areas (% of total land area)  \
# Year
# 1960                                                          NaN
# 1961                                                          NaN
#
# Indicator Name  Total fisheries production (metric tons)  \
# Year
# 1960                                            196513.0
# 1961                                            224915.0
#
# Indicator Name  Total greenhouse gas emissions (% change from 1990)  \
# Year
# 1960                                                          NaN
# 1961                                                          NaN
#
# Indicator Name  Total greenhouse gas emissions (kt of CO2 equivalent)  \
# Year
# 1960                                                          NaN
# 1961                                                          NaN
#
# Indicator Name  Total natural resources rents (% of GDP)  \
# Year
# 1960                                                 NaN
# 1961                                                 NaN
#
# Indicator Name  Urban land area (sq. km)  \
# Year
# 1960                                 NaN
# 1961                                 NaN
#
# Indicator Name  Urban land area where elevation is below 5 meters (% of total land area)  \
# Year
# 1960                                                          NaN
# 1961                                                          NaN
#
# Indicator Name  Urban land area where elevation is below 5 meters (sq. km)  \
# Year
# 1960                                                          NaN
# 1961                                                          NaN
#
# Indicator Name  Urban population living in areas where elevation is below 5 meters (% of total population)  \
# Year
# 1960                                                          NaN
# 1961                                                          NaN
#
# Indicator Name  Water productivity, total (constant 2015 US$ GDP per cubic meter of total freshwater withdrawal)
# Year
# 1960                                                          NaN
# 1961                                                          NaN
#
# [2 rows x 129 columns]

# %%
# Out:
# 129

# %% [markdown]
# ## Now it's easier to check columns.
# Considering that there are 129 columns, I think it's a good idea to select the ones that I want to analyze and create a new dataframe with them.

# %%
# Check the name of the columns
pivot1.columns
# Out:
# Index(['Access to clean fuels and technologies for cooking (% of population)',
#        'Access to clean fuels and technologies for cooking, rural (% of rural population)',
#        'Access to clean fuels and technologies for cooking, urban (% of urban population)',
#        'Access to electricity (% of population)',
#        'Adjusted net savings, excluding particulate emission damage (% of GNI)',
#        'Adjusted net savings, excluding particulate emission damage (current US$)',
#        'Adjusted net savings, including particulate emission damage (% of GNI)',
#        'Adjusted net savings, including particulate emission damage (current US$)',
#        'Adjusted savings: carbon dioxide damage (% of GNI)',
#        'Adjusted savings: carbon dioxide damage (current US$)',
#        ...
#        'Terrestrial protected areas (% of total land area)',
#        'Total fisheries production (metric tons)',
#        'Total greenhouse gas emissions (% change from 1990)',
#        'Total greenhouse gas emissions (kt of CO2 equivalent)',
#        'Total natural resources rents (% of GDP)', 'Urban land area (sq. km)',
#        'Urban land area where elevation is below 5 meters (% of total land area)',
#        'Urban land area where elevation is below 5 meters (sq. km)',
#        'Urban population living in areas where elevation is below 5 meters (% of total population)',
#        'Water productivity, total (constant 2015 US$ GDP per cubic meter of total freshwater withdrawal)'],
#       dtype='object', name='Indicator Name', length=129)

# %%
# There are lots of missing values. Let's count them:

missing_values_count = pivot1.isnull().sum()
missing_values_count
# Out:
# Indicator Name
# Access to clean fuels and technologies for cooking (% of population)                                41
# Access to clean fuels and technologies for cooking, rural (% of rural population)                   41
# Access to clean fuels and technologies for cooking, urban (% of urban population)                   41
# Access to electricity (% of population)                                                             33
# Adjusted net savings, excluding particulate emission damage (% of GNI)                              20
#                                                                                                     ..
# Urban land area (sq. km)                                                                            59
# Urban land area where elevation is below 5 meters (% of total land area)                            59
# Urban land area where elevation is below 5 meters (sq. km)                                          59
# Urban population living in areas where elevation is below 5 meters (% of total population)          59
# Water productivity, total (constant 2015 US$ GDP per cubic meter of total freshwater withdrawal)    54
# Length: 129, dtype: int64

# %% [markdown]
# Now I can make a correlation heat map to find interesting relationships between values
#
# ### I'll save this code as a template for future uses
#
#     correlations = pd.concat([pivot1["Adjusted savings: net national savings (current US$)"], pivot1["Agricultural land (% of land area)"], pivot1["Aquaculture production (metric tons)"]], axis=1 )
#     corrmat = correlations.corr()
#     f, ax = plt.subplots(figsize=(20, 9))
#     sns.heatmap(corrmat, vmax=.8, square=True)

# %%
# I'll save this table so I can upload it to Kaggle :D
pivot1.to_csv("datasets/WB_MX_Environment_indicators.csv")

# %% [markdown]
# # Total greenhouse gas emissions (% change from 1990)

# %%
hist_ = pivot1['Total greenhouse gas emissions (% change from 1990)']
hist_.dropna()
pivot1['Total greenhouse gas emissions (% change from 1990)'].describe()
# Out:
# count    22.000000
# mean     18.663572
# std      12.637721
# min       0.100095
# 25%       8.142528
# 50%      15.782376
# 75%      30.318425
# max      40.103562
# Name: Total greenhouse gas emissions (% change from 1990), dtype: float64

# %%
hist_.dropna()
# Out:
# Year
# 1991     2.230696
# 1992     0.100095
# 1993     1.612875
# 1994     5.276677
# 1995     4.413669
# 1996     7.822185
# 1997     9.103557
# 1998    40.103562
# 1999    12.080582
# 2000    16.662619
# 2001    10.889295
# 2002    14.879791
# 2003    21.761505
# 2004    14.902133
# 2005    29.779924
# 2006    29.947677
# 2007    30.793752
# 2008    30.358521
# 2009    31.308052
# 2010    30.198139
# 2011    32.117767
# 2012    34.255506
# Name: Total greenhouse gas emissions (% change from 1990), dtype: float64

# %%
hist_.plot.hist(figsize=(4,4))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
hist_.plot.line()
# Out:
# <AxesSubplot:xlabel='Year'>

# %% [markdown]
# **What happened between 1995 and 2000?**
# I'll try to understand how it was calculated.

# %%
# Filter all CO2 and greenhouse gas related columns
df_co2 = pivot1.filter(like="CO2", axis=1)
df_greenhouse = pivot1.filter(like="greenhouse", axis=1)
df_full = pd.concat([df_co2, df_greenhouse], axis=1)

# Remove duplicated columns
df_full = df_full.loc[:,~df_full.columns.duplicated()].copy()
df_full.columns
# Out:
# Index(['Agricultural methane emissions (thousand metric tons of CO2 equivalent)',
#        'Agricultural nitrous oxide emissions (thousand metric tons of CO2 equivalent)',
#        'CO2 emissions (kg per 2015 US$ of GDP)',
#        'CO2 emissions (kg per 2017 PPP $ of GDP)',
#        'CO2 emissions (kg per PPP $ of GDP)', 'CO2 emissions (kt)',
#        'CO2 emissions (metric tons per capita)',
#        'CO2 emissions from gaseous fuel consumption (% of total)',
#        'CO2 emissions from gaseous fuel consumption (kt)',
#        'CO2 emissions from liquid fuel consumption (% of total)',
#        'CO2 emissions from liquid fuel consumption (kt)',
#        'CO2 emissions from solid fuel consumption (% of total)',
#        'CO2 emissions from solid fuel consumption (kt)',
#        'CO2 intensity (kg per kg of oil equivalent energy use)',
#        'GHG net emissions/removals by LUCF (Mt of CO2 equivalent)',
#        'HFC gas emissions (thousand metric tons of CO2 equivalent)',
#        'Methane emissions (kt of CO2 equivalent)',
#        'Methane emissions in energy sector (thousand metric tons of CO2 equivalent)',
#        'Nitrous oxide emissions (thousand metric tons of CO2 equivalent)',
#        'Nitrous oxide emissions in energy sector (thousand metric tons of CO2 equivalent)',
#        'Other greenhouse gas emissions, HFC, PFC and SF6 (thousand metric tons of CO2 equivalent)',
#        'PFC gas emissions (thousand metric tons of CO2 equivalent)',
#        'SF6 gas emissions (thousand metric tons of CO2 equivalent)',
#        'Total greenhouse gas emissions (kt of CO2 equivalent)',
#        'Other greenhouse gas emissions (% change from 1990)',
#        'Total greenhouse gas emissions (% change from 1990)'],
#       dtype='object', name='Indicator Name')

# %%
nan_values = df_full.isnull().sum()
nan_values
# Out:
# Indicator Name
# Agricultural methane emissions (thousand metric tons of CO2 equivalent)                      32
# Agricultural nitrous oxide emissions (thousand metric tons of CO2 equivalent)                32
# CO2 emissions (kg per 2015 US$ of GDP)                                                       33
# CO2 emissions (kg per 2017 PPP $ of GDP)                                                     32
# CO2 emissions (kg per PPP $ of GDP)                                                          32
# CO2 emissions (kt)                                                                           32
# CO2 emissions (metric tons per capita)                                                       32
# CO2 emissions from gaseous fuel consumption (% of total)                                      5
# CO2 emissions from gaseous fuel consumption (kt)                                              5
# CO2 emissions from liquid fuel consumption (% of total)                                       5
# CO2 emissions from liquid fuel consumption (kt)                                               5
# CO2 emissions from solid fuel consumption (% of total)                                        5
# CO2 emissions from solid fuel consumption (kt)                                                5
# CO2 intensity (kg per kg of oil equivalent energy use)                                       17
# GHG net emissions/removals by LUCF (Mt of CO2 equivalent)                                    61
# HFC gas emissions (thousand metric tons of CO2 equivalent)                                   57
# Methane emissions (kt of CO2 equivalent)                                                     32
# Methane emissions in energy sector (thousand metric tons of CO2 equivalent)                  32
# Nitrous oxide emissions (thousand metric tons of CO2 equivalent)                             32
# Nitrous oxide emissions in energy sector (thousand metric tons of CO2 equivalent)            32
# Other greenhouse gas emissions, HFC, PFC and SF6 (thousand metric tons of CO2 equivalent)    15
# PFC gas emissions (thousand metric tons of CO2 equivalent)                                   57
# SF6 gas emissions (thousand metric tons of CO2 equivalent)                                   57
# Total greenhouse gas emissions (kt of CO2 equivalent)                                        32
# Other greenhouse gas emissions (% change from 1990)                                          40
# Total greenhouse gas emissions (% change from 1990)                                          40
# dtype: int64

# %%
total_co2 = df_co2["Total greenhouse gas emissions (kt of CO2 equivalent)"].dropna()
# Calculate the percentage of change from 1990.
for x in total_co2:
    print(((x - total_co2[0])/total_co2[0])*100)
# Out:
# 0.0
# 4.667081518357187
# 5.396388967213694
# 9.70752955818295
# 16.32607251720995
# 11.233355291303802
# 16.00995826365127
# 21.712510513087246
# 27.920344221569636
# 25.209707225711757
# 31.98257379822651
# 32.12196335854859
# 34.185445390284755
# 40.12695008653541
# 43.02924582879601
# 48.62725210990988
# 53.829498385967646
# 56.93091990121344
# 57.95146417528786
# 55.586809539320214
# 60.02737352695233
# 65.0205278663659
# 67.29806972425338
# 63.902919842874915
# 61.64529511998283
# 66.03608905861083
# 67.76602364654636
# 67.1686311352677
# 62.850031113876796
# 62.75544371305239

# %% [markdown]
# **The results are very different from the calculation in the table!**

# %%
# Try with a diagonal correlation matrix

# Compute correlation matrix
corr = df_full.corr()

# Generate mask for upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# generate custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw heatmap with mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:xlabel='Indicator Name', ylabel='Indicator Name'>

# %% [markdown]
# # Greenhouse gas emissions by sector in Mexico
# million metric tonnes of carbon dioxide equivalents
#
# First, I'll check for the most CO2 eq contaminant sectors in Mexico, so I can limit the investigation to the most contaminant ones and try to find a correlation within those sectors and the extreme percentage of change between 1995 and 2000

# %%
df_ghge = pd.read_csv("datasets/ghg-emissions-by-sector.csv")
df_ghge.columns
# Out:
# Index(['Entity', 'Code', 'Year', 'Agriculture', 'Land-use change and forestry',
#        'Waste', 'Industry', 'Manufacturing and construction', 'Transport',
#        'Electricity and heat', 'Buildings', 'Fugitive emissions',
#        'Other fuel combustion', 'Aviation and shipping'],
#       dtype='object')

# %%
# I can pivot this table to use Countries as columns and years as index
df_ghge_mexico = df_ghge.query("Entity == 'Mexico'")
df_ghge_mexico.drop(['Entity', 'Code'], axis=1, inplace=True)
df_ghge_mexico
# Out:
# /tmp/ipykernel_31544/4125103533.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ghge_mexico.drop(['Entity', 'Code'], axis=1, inplace=True)
#       Year   Agriculture  Land-use change and forestry         Waste  \
# 3510  1990  8.878000e+07                  2.454000e+07  8.020000e+06
# 3511  1991  8.706000e+07                  2.454000e+07  8.690000e+06
# 3512  1992  8.640000e+07                  2.454000e+07  9.350000e+06
# 3513  1993  8.789000e+07                  2.454000e+07  1.521000e+07
# 3514  1994  8.774000e+07                  2.454000e+07  1.583000e+07
# 3515  1995  8.600000e+07                  2.454000e+07  1.645000e+07
# 3516  1996  8.493000e+07                  2.400000e+07  1.700000e+07
# 3517  1997  8.551000e+07                  2.424000e+07  1.695000e+07
# 3518  1998  8.743000e+07                  3.266000e+07  1.692000e+07
# 3519  1999  8.531000e+07                  2.777000e+07  1.774000e+07
# 3520  2000  8.619000e+07                  2.779000e+07  1.878000e+07
# 3521  2001  8.667000e+07                 -6.595000e+07  1.937000e+07
# 3522  2002  8.534000e+07                 -6.518000e+07  2.017000e+07
# 3523  2003  8.620000e+07                 -6.339000e+07  2.086000e+07
# 3524  2004  8.550000e+07                 -6.621000e+07  2.181000e+07
# 3525  2005  8.750000e+07                 -6.455000e+07  2.315000e+07
# 3526  2006  8.663000e+07                 -6.511000e+07  2.545000e+07
# 3527  2007  8.801000e+07                 -6.560000e+07  2.696000e+07
# 3528  2008  8.759000e+07                 -6.513000e+07  2.853000e+07
# 3529  2009  8.902000e+07                 -6.522000e+07  2.956000e+07
# 3530  2010  8.981000e+07                 -6.593000e+07  3.097000e+07
# 3531  2011  9.143000e+07                  1.609000e+07  3.280000e+07
# 3532  2012  9.109000e+07                  1.491000e+07  3.289000e+07
# 3533  2013  9.400000e+07                  1.616000e+07  2.629000e+07
# 3534  2014  8.988000e+07                  1.405000e+07  3.526000e+07
# 3535  2015  9.088000e+07                  1.489000e+07  4.422000e+07
# 3536  2016  9.559000e+07                  1.571000e+07  4.507000e+07
# 3537  2017  9.681000e+07                  1.646000e+07  4.591000e+07
# 3538  2018  9.682000e+07                  1.538000e+07  4.676000e+07
# 3539  2019  9.854000e+07                  1.697000e+07  4.760000e+07
#
#           Industry  Manufacturing and construction     Transport  \
# 3510  1.326000e+07                    5.355000e+07  8.612000e+07
# 3511  1.367000e+07                    5.228000e+07  9.216000e+07
# 3512  1.389000e+07                    5.196000e+07  9.247000e+07
# 3513  1.490000e+07                    5.025000e+07  9.461000e+07
# 3514  1.614000e+07                    5.111000e+07  1.004400e+08
# 3515  1.383000e+07                    4.953000e+07  9.217000e+07
# 3516  1.707000e+07                    5.510000e+07  9.455000e+07
# 3517  1.801000e+07                    5.521000e+07  9.868000e+07
# 3518  1.855000e+07                    5.662000e+07  1.013200e+08
# 3519  1.996000e+07                    5.208000e+07  1.041100e+08
# 3520  2.028000e+07                    5.314000e+07  1.087900e+08
# 3521  1.960000e+07                    4.808000e+07  1.111400e+08
# 3522  2.086000e+07                    5.167000e+07  1.131200e+08
# 3523  2.135000e+07                    5.262000e+07  1.199100e+08
# 3524  2.315000e+07                    5.654000e+07  1.264900e+08
# 3525  2.521000e+07                    5.899000e+07  1.341800e+08
# 3526  2.868000e+07                    6.648000e+07  1.415800e+08
# 3527  3.148000e+07                    6.240000e+07  1.495700e+08
# 3528  3.226000e+07                    6.464000e+07  1.557400e+08
# 3529  3.224000e+07                    5.232000e+07  1.521900e+08
# 3530  3.255000e+07                    6.243000e+07  1.551500e+08
# 3531  3.427000e+07                    6.823000e+07  1.562500e+08
# 3532  3.495000e+07                    6.174000e+07  1.571100e+08
# 3533  3.508000e+07                    6.605000e+07  1.552000e+08
# 3534  3.651000e+07                    5.926000e+07  1.557900e+08
# 3535  3.803000e+07                    6.628000e+07  1.550900e+08
# 3536  3.716000e+07                    6.215000e+07  1.606300e+08
# 3537  3.837000e+07                    6.867000e+07  1.559900e+08
# 3538  4.204000e+07                    5.597000e+07  1.518800e+08
# 3539  4.281000e+07                    5.653000e+07  1.517800e+08
#
#       Electricity and heat     Buildings  Fugitive emissions  \
# 3510          9.451000e+07  2.325000e+07        2.910000e+07
# 3511          1.069300e+08  2.428000e+07        3.009000e+07
# 3512          1.079100e+08  2.622000e+07        2.983000e+07
# 3513          1.145400e+08  2.671000e+07        3.120000e+07
# 3514          1.308600e+08  2.796000e+07        3.215000e+07
# 3515          1.223100e+08  2.797000e+07        3.337000e+07
# 3516          1.277200e+08  2.773000e+07        3.629000e+07
# 3517          1.419100e+08  2.736000e+07        3.929000e+07
# 3518          1.592600e+08  2.843000e+07        3.936000e+07
# 3519          1.532000e+08  2.613000e+07        3.784000e+07
# 3520          1.688900e+08  2.875000e+07        3.879000e+07
# 3521          1.730900e+08  2.812000e+07        3.816000e+07
# 3522          1.751600e+08  2.831000e+07        3.814000e+07
# 3523          1.868600e+08  2.718000e+07        4.123000e+07
# 3524          1.851100e+08  2.773000e+07        4.120000e+07
# 3525          1.921300e+08  2.679000e+07        4.167000e+07
# 3526          1.910900e+08  2.723000e+07        4.299000e+07
# 3527          1.942600e+08  2.655000e+07        4.307000e+07
# 3528          1.868600e+08  2.652000e+07        4.396000e+07
# 3529          1.941000e+08  2.546000e+07        4.152000e+07
# 3530          1.958800e+08  2.607000e+07        4.145000e+07
# 3531          2.050800e+08  2.573000e+07        4.027000e+07
# 3532          2.128600e+08  2.601000e+07        4.599000e+07
# 3533          2.020900e+08  2.504000e+07        4.576000e+07
# 3534          1.925800e+08  2.522000e+07        4.594000e+07
# 3535          1.941400e+08  2.489000e+07        4.382000e+07
# 3536          1.972800e+08  2.408000e+07        4.222000e+07
# 3537          1.952600e+08  2.383000e+07        3.674000e+07
# 3538          1.896200e+08  2.363000e+07        3.718000e+07
# 3539          1.866200e+08  2.244000e+07        3.799000e+07
#
#       Other fuel combustion  Aviation and shipping
# 3510           5.160000e+06           5.330000e+06
# 3511           5.340000e+06           5.550000e+06
# 3512           5.390000e+06           6.140000e+06
# 3513           5.420000e+06           7.230000e+06
# 3514           5.110000e+06           9.650000e+06
# 3515           5.260000e+06           9.490000e+06
# 3516           5.680000e+06           9.360000e+06
# 3517           6.060000e+06           9.810000e+06
# 3518           6.040000e+06           1.120000e+07
# 3519           6.660000e+06           1.203000e+07
# 3520           6.640000e+06           1.212000e+07
# 3521           6.570000e+06           1.193000e+07
# 3522           6.330000e+06           1.067000e+07
# 3523           6.740000e+06           1.089000e+07
# 3524           7.070000e+06           1.119000e+07
# 3525           7.480000e+06           1.144000e+07
# 3526           7.880000e+06           1.189000e+07
# 3527           8.180000e+06           1.277000e+07
# 3528           8.480000e+06           1.284000e+07
# 3529           8.670000e+06           1.055000e+07
# 3530           8.620000e+06           1.079000e+07
# 3531           8.910000e+06           1.119000e+07
# 3532           9.470000e+06           1.169000e+07
# 3533           8.970000e+06           1.172000e+07
# 3534           8.980000e+06           1.239000e+07
# 3535           9.700000e+06           1.309000e+07
# 3536           9.840000e+06           1.403000e+07
# 3537           1.002000e+07           1.451000e+07
# 3538           1.036000e+07           1.519000e+07
# 3539           9.570000e+06           1.504000e+07

# %%
# A global table from the last year in the table (2019)
row_2019 = df_ghge_mexico.filter(items=[3539], axis=0)
row_2019
# Out:
#       Year   Agriculture  Land-use change and forestry         Waste  \
# 3539  2019  9.854000e+07                  1.697000e+07  4.760000e+07
#
#           Industry  Manufacturing and construction     Transport  \
# 3539  4.281000e+07                    5.653000e+07  1.517800e+08
#
#       Electricity and heat     Buildings  Fugitive emissions  \
# 3539          1.866200e+08  2.244000e+07        3.799000e+07
#
#       Other fuel combustion  Aviation and shipping
# 3539           9.570000e+06           1.504000e+07

# %%
row_2019 = pd.melt(row_2019)

row_2019
# Out:
#                           variable         value
# 0                             Year  2.019000e+03
# 1                      Agriculture  9.854000e+07
# 2     Land-use change and forestry  1.697000e+07
# 3                            Waste  4.760000e+07
# 4                         Industry  4.281000e+07
# 5   Manufacturing and construction  5.653000e+07
# 6                        Transport  1.517800e+08
# 7             Electricity and heat  1.866200e+08
# 8                        Buildings  2.244000e+07
# 9               Fugitive emissions  3.799000e+07
# 10           Other fuel combustion  9.570000e+06
# 11           Aviation and shipping  1.504000e+07

# %%
row_2019 = row_2019.rename(columns={"variable":"Category", "value":"MMTCDE"})
row_2019 = row_2019.sort_values(by=["MMTCDE"], ascending=False)
row_2019.plot.bar(x="Category", y="MMTCDE")
# Out:
# <AxesSubplot:xlabel='Category'>

# %% [markdown]
# # Making a code for a new table for later.
#     df_deaths = pd.read_csv("datasets/number-of-deaths-by-risk-factor.csv")
#     df_deaths_mexico = df_deaths.query("Entity == 'Mexico'")
#     df_deaths_mexico.drop(['Entity', 'Code'], axis=1, inplace=True)
#     df_deaths_mexico

# %%
df_fossil = pd.read_csv("datasets/fossil-fuels-share-energy.csv")
df_fossil.columns
# Out:
# Index(['Entity', 'Code', 'Year', 'Fossil fuels (% equivalent primary energy)'], dtype='object')

# %%
df_fossil = df_fossil.query("Entity == 'Mexico'")
df_fossil.drop(['Entity', 'Code'], axis=1, inplace=True)
df_fossil.head(2)
# Out:
#       Year  Fossil fuels (% equivalent primary energy)
# 2917  1965                                   91.065277
# 2918  1966                                   90.366890

# %%
df_fossil.pct_change()
# Out:
#           Year  Fossil fuels (% equivalent primary energy)
# 2917       NaN                                         NaN
# 2918  0.000509                                   -0.007669
# 2919  0.000509                                   -0.007284
# 2920  0.000508                                   -0.006148
# 2921  0.000508                                    0.004122
# 2922  0.000508                                   -0.005657
# 2923  0.000508                                    0.009425
# 2924  0.000507                                    0.004036
# 2925  0.000507                                    0.001460
# 2926  0.000507                                    0.006128
# 2927  0.000507                                    0.014413
# 2928  0.000506                                   -0.005682
# 2929  0.000506                                   -0.004688
# 2930  0.000506                                    0.023452
# 2931  0.000506                                   -0.001600
# 2932  0.000505                                    0.010121
# 2933  0.000505                                   -0.018406
# 2934  0.000505                                    0.007509
# 2935  0.000505                                    0.005737
# 2936  0.000504                                   -0.005578
# 2937  0.000504                                   -0.010618
# 2938  0.000504                                    0.013278
# 2939  0.000504                                    0.005118
# 2940  0.000503                                   -0.007094
# 2941  0.000503                                   -0.006394
# 2942  0.000503                                   -0.001134
# 2943  0.000503                                    0.002707
# 2944  0.000502                                   -0.009080
# 2945  0.000502                                   -0.001811
# 2946  0.000502                                    0.021295
# 2947  0.000502                                   -0.026920
# 2948  0.000501                                   -0.003592
# 2949  0.000501                                    0.007784
# 2950  0.000501                                    0.009454
# 2951  0.000501                                   -0.016819
# 2952  0.000500                                    0.005999
# 2953  0.000500                                    0.007816
# 2954  0.000500                                    0.008407
# 2955  0.000500                                    0.007476
# 2956  0.000499                                   -0.003701
# 2957  0.000499                                   -0.003320
# 2958  0.000499                                   -0.000681
# 2959  0.000499                                    0.004903
# 2960  0.000498                                   -0.014606
# 2961  0.000498                                    0.017845
# 2962  0.000498                                   -0.007184
# 2963  0.000498                                   -0.000925
# 2964  0.000497                                    0.006473
# 2965  0.000497                                    0.000486
# 2966  0.000497                                   -0.015055
# 2967  0.000497                                    0.004900
# 2968  0.000496                                    0.000714
# 2969  0.000496                                   -0.002728
# 2970  0.000496                                   -0.009462
# 2971  0.000496                                    0.001238
# 2972  0.000495                                   -0.029012
# 2973  0.000495                                   -0.011802

# %% [markdown]
# # TODO Clean pivot1 table. It's full of columns with more than 50% of NaN values and it affects the correlation maps.

# %%
df_fossil.pct_change()
# Out:
#           Year  Fossil fuels (% equivalent primary energy)
# 2917       NaN                                         NaN
# 2918  0.000509                                   -0.007669
# 2919  0.000509                                   -0.007284
# 2920  0.000508                                   -0.006148
# 2921  0.000508                                    0.004122
# 2922  0.000508                                   -0.005657
# 2923  0.000508                                    0.009425
# 2924  0.000507                                    0.004036
# 2925  0.000507                                    0.001460
# 2926  0.000507                                    0.006128
# 2927  0.000507                                    0.014413
# 2928  0.000506                                   -0.005682
# 2929  0.000506                                   -0.004688
# 2930  0.000506                                    0.023452
# 2931  0.000506                                   -0.001600
# 2932  0.000505                                    0.010121
# 2933  0.000505                                   -0.018406
# 2934  0.000505                                    0.007509
# 2935  0.000505                                    0.005737
# 2936  0.000504                                   -0.005578
# 2937  0.000504                                   -0.010618
# 2938  0.000504                                    0.013278
# 2939  0.000504                                    0.005118
# 2940  0.000503                                   -0.007094
# 2941  0.000503                                   -0.006394
# 2942  0.000503                                   -0.001134
# 2943  0.000503                                    0.002707
# 2944  0.000502                                   -0.009080
# 2945  0.000502                                   -0.001811
# 2946  0.000502                                    0.021295
# 2947  0.000502                                   -0.026920
# 2948  0.000501                                   -0.003592
# 2949  0.000501                                    0.007784
# 2950  0.000501                                    0.009454
# 2951  0.000501                                   -0.016819
# 2952  0.000500                                    0.005999
# 2953  0.000500                                    0.007816
# 2954  0.000500                                    0.008407
# 2955  0.000500                                    0.007476
# 2956  0.000499                                   -0.003701
# 2957  0.000499                                   -0.003320
# 2958  0.000499                                   -0.000681
# 2959  0.000499                                    0.004903
# 2960  0.000498                                   -0.014606
# 2961  0.000498                                    0.017845
# 2962  0.000498                                   -0.007184
# 2963  0.000498                                   -0.000925
# 2964  0.000497                                    0.006473
# 2965  0.000497                                    0.000486
# 2966  0.000497                                   -0.015055
# 2967  0.000497                                    0.004900
# 2968  0.000496                                    0.000714
# 2969  0.000496                                   -0.002728
# 2970  0.000496                                   -0.009462
# 2971  0.000496                                    0.001238
# 2972  0.000495                                   -0.029012
# 2973  0.000495                                   -0.011802

# %% [markdown]
# # TODO Clean pivot1 table. It's full of columns with more than 50% of NaN values and it affects the correlation maps.
